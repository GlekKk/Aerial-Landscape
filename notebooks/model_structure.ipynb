# %%
import sys
import os
import torch
from torchinfo import summary

sys.path.append(os.path.abspath('../src'))
from model import SimpleCNN

# %% [markdown]
# ## Architecture inspection

# %%
model = SimpleCNN(num_classes=15)

model
# Out:
# SimpleCNN(
#   (features1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (features2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (features3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (features4): Sequential(
# ...

# %% [markdown]
# ## Model summary

# %%
summary(model, input_size=(64, 3, 224, 224))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# SimpleCNN                                [64, 15]                  --
# ├─Sequential: 1-1                        [64, 16, 112, 112]        --
# │    └─Conv2d: 2-1                       [64, 16, 224, 224]        448
# │    └─BatchNorm2d: 2-2                  [64, 16, 224, 224]        32
# │    └─ReLU: 2-3                         [64, 16, 224, 224]        --
# │    └─MaxPool2d: 2-4                    [64, 16, 112, 112]        --
# ├─Sequential: 1-2                        [64, 32, 56, 56]          --
# │    └─Conv2d: 2-5                       [64, 32, 112, 112]        4,640
# │    └─BatchNorm2d: 2-6                  [64, 32, 112, 112]        64
# │    └─ReLU: 2-7                         [64, 32, 112, 112]        --
# │    └─MaxPool2d: 2-8                    [64, 32, 56, 56]          --
# ├─Sequential: 1-3                        [64, 64, 28, 28]          --
# ...

# %% [markdown]
# The torchinfo summary acts as a diagnostic X-ray for the neural network architecture defined in model.py. By examining the Output Shape column, we can track exactly how the image dimensions compress and the feature channels expand as they pass through each convolutional block. Most importantly, it validates the transition from 2D feature maps to 1D vectors. Additionally, the parameter count provides a clear view of the model's complexity, showing exactly where the network stores its trainable weights.

# %% [markdown]
# The Output Shape column tracks exactly how the data tensor transforms as it flows through the network, represented in the format [Batch Size, Channels, Height, Width].
#
# The most critical part of this shape is the number of Channels, which represent the network's feature maps. As the image passes through deeper convolutional blocks, the spatial dimensions (height and width) shrink due to pooling, but the number of feature maps expands (e.g., from 16 to 32, and then to 64). This perfectly illustrates how a Convolutional Neural Network learns: it trades spatial resolution for semantic depth. While the early layers use a few feature maps to detect simple visual primitives like edges and colors, the deeper layers use dozens of feature maps to recognize complex, high-level patterns like a forest canopy or a sandy beach.
